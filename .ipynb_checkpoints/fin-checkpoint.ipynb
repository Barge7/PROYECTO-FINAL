# %%
import pandas as pd
from selenium import webdriver

import time
from tqdm import tqdm
import regex as re
import warnings
warnings.filterwarnings('ignore')

from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By   # para buscar segun tag, id, class, etc...

from selenium.webdriver.support.ui import WebDriverWait   # es para esperar

from selenium.webdriver.support import expected_conditions as EC  # condiciones esperadas...

from selenium.webdriver import ActionChains as AC   # acciones encadenadas, rollo doble click

from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

PATH=ChromeDriverManager().install()
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.58M/6.58M [00:02<00:00, 3.08MB/s]

# %%
data = pd.read_excel('ciudades.xlsx')

# %%
data1 = pd.read_excel('vuelos.xlsx')

# %%
data2 = pd.read_excel('links.xlsx')

# %%
data3= pd.read_excel('poblacion.xlsx')

# %%
data4 = pd.read_excel('restaurantes.xlsx')

# %%
data5 = pd.read_excel('coste.xlsx')

# %%
data6 = pd.read_excel('temperaturas.xlsx')

# %%
data = data.set_index('ciudades_id').join(data6.set_index('ciudad')).join(data1.set_index('ciudades_id')).join(data2.set_index('ciudad')).join(data3.set_index('ciudad')).join(data4.set_index('ciudades_id')).join(data5.set_index('ciudades_id'))

# %%
data.drop(['pais', 'link_nocturno', 'link_monumentos', 'link_acuaticos', 'link_museos', 'link_spas', 'link_diversion', 'link_naturaleza'], axis= 1, inplace = True)

# %%
data['presupuesto']= data['precio/vuelo'] + data['calculo_viaje']

# %%
data.to_excel('final.xlsx', index= False)

# %%
data
# Out:
#                                 ciudades  Temp  precio/vuelo  \
# ciudades_id
# 1                         Albania-Tirana   7.6           196
# 2                          Austria-Viena   4.2           155
# 3                      Bielorrusia-Minsk  -3.9          1943
# 4                         Bulgaria-Sofia   2.0           233
# 5                   Dinamarca-Copenhague   2.2           109
# 6                    Eslovenia-Liubliana   1.2           230
# 7                         Estonia-Tallín  -6.2           375
# 8                          Francia-Paris   7.0           162
# 9                          Grecia-Atenas  12.2           412
# 10                        Irlanda-Dublin   7.0            58
# 11                           Italia-Roma   9.2           189
# 12                        Lituania-Vilna  -3.9           226
# 13                      Macedonia-Skopie   2.9           435
# 14                     Moldavia-Chisinau   0.4           551
# 15                Paises Bajos-Amsterdam   5.7           134
# 16                       Portugal-Lisboa  13.8            53
# 17                 República Checa-Praga   1.3           274
# 18                      Suecia-Estocolmo  -2.4           146
# 19                       Alemania-Berlin   1.9           181
# 20                      Belgica-Bruselas   5.8            92
# 21           Bosnia Hercegovina-Sarajevo   2.3           326
# 22                        Croacia-Zagreb   2.9           322
# 23                 Eslovaquia-Bratislava   2.3           172
# 24                    Finlandia-Helsinki  -6.7           368
# 25                      Hungría-Budapest   1.2           158
# 26                    Islandia-Reikiavik   1.6           536
# 27                          Letonia-Riga  -2.0           348
# 28                 Luxemburgo-Luxemburgo   3.7           130
# 29                       Malta-La Valeta  13.5           199
# 30                          Noruega-Oslo  -4.8           315
# 31                      Polonia-Varsovia  -0.9           108
# 32                      Rumania-Bucarest   2.5           189
# 33                       Serbia-Belgrado   4.0           378
#
#                                                          links  vida_nocturna  \
# ciudades_id
# 1            https://www.tripadvisor.es/Attractions-g294446...             57
# 2            https://www.tripadvisor.es/Attractions-g190454...            119
# 3            https://www.tripadvisor.es/Attractions-g294448...             36
# 4            https://www.tripadvisor.es/Attractions-g294452...            106
# 5            https://www.tripadvisor.es/Attractions-g189541...            125
# 6            https://www.tripadvisor.es/Attractions-g274873...             54
# 7            https://www.tripadvisor.es/Attractions-g274958...             52
# 8            https://www.tripadvisor.es/Attractions-g187147...            329
# 9            https://www.tripadvisor.es/Attractions-g189400...            169
# 10           https://www.tripadvisor.es/Attractions-g186605...            212
# 11           https://www.tripadvisor.es/Attractions-g187791...            327
# 12           https://www.tripadvisor.es/Attractions-g274951...             56
# 13           https://www.tripadvisor.es/Attractions-g295110...             21
# 14           https://www.tripadvisor.es/Attractions-g294456...             21
# 15           https://www.tripadvisor.es/Attractions-g188590...            381
# 16           https://www.tripadvisor.es/Attractions-g189158...            157
# 17           https://www.tripadvisor.es/Attractions-g274707...            404
# 18           https://www.tripadvisor.es/Attractions-g189852...             20
# 19           https://www.tripadvisor.es/Attractions-g187323...            372
# 20           https://www.tripadvisor.es/Attractions-g188644...            107
# 21           https://www.tripadvisor.es/Attractions-g294450...             27
# 22           https://www.tripadvisor.es/Attractions-g294454...             83
# 23           https://www.tripadvisor.es/Attractions-g274924...             61
# 24           https://www.tripadvisor.es/Attractions-g189934...             50
# 25           https://www.tripadvisor.es/Attractions-g274887...            213
# 26           https://www.tripadvisor.es/Attractions-g189970...             40
# 27           https://www.tripadvisor.es/Attractions-g274967...             63
# 28           https://www.tripadvisor.es/Attractions-g190340...             16
# 29           https://www.tripadvisor.es/Attractions-g190328...              7
# 30           https://www.tripadvisor.es/Attractions-g190479...             48
# 31           https://www.tripadvisor.es/Attractions-g274856...             93
# 32           https://www.tripadvisor.es/Attractions-g294458...            103
# 33           https://www.tripadvisor.es/Attractions-g294472...            129
#
#              monumentos  deportes_agua  museos  spas  diversion  ...  \
# ciudades_id                                                      ...
# 1                    30             27      14    23         18  ...
# 2                   295              9     119    41        106  ...
# 3                    68              6      45    20         64  ...
# 4                   110              7      47    47         76  ...
# 5                   174              5      66    41         58  ...
# 6                    67              6      30    24         35  ...
# 7                    92             18      75    23         59  ...
# 8                     1            100     231   304        227  ...
# 9                   259            107      89    62         77  ...
# 10                  270              5      81    59         72  ...
# 11                  926             42     181   184        134  ...
# 12                  105              8      58    38         47  ...
# 13                   34             10      12    13         13  ...
# 14                   35              4      12    18         19  ...
# 15                  256            143     149    88        121  ...
# 16                  430            137     109   125         59  ...
# 17                  581             44     212   136        254  ...
# 18                  133             22      62    24         52  ...
# 19                  380             10     194   111        129  ...
# 20                  238              9      98    34         51  ...
# 21                   70              9      24    13         16  ...
# 22                   52             18      42    27         46  ...
# 23                  105              6      39    17         67  ...
# 24                  177             27      59    38         56  ...
# 25                  242             62     116   118        173  ...
# 26                   47             60      39    21         28  ...
# 27                  102             30      65    89         80  ...
# 28                  138              5      42    17         26  ...
# 29                  110             18      21     2          4  ...
# 30                  156             15      69    18         41  ...
# 31                  197              6      72    88        104  ...
# 32                  106             11      51    58         84  ...
# 33                   79              5      47    44         48  ...
