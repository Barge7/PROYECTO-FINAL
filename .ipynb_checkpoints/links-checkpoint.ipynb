# %%
import pandas as pd
from selenium import webdriver

import time
from tqdm import tqdm
import regex as re
import warnings
warnings.filterwarnings('ignore')

from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By   # para buscar segun tag, id, class, etc...

from selenium.webdriver.support.ui import WebDriverWait   # es para esperar

from selenium.webdriver.support import expected_conditions as EC  # condiciones esperadas...

from selenium.webdriver import ActionChains as AC   # acciones encadenadas, rollo doble click

from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

PATH=ChromeDriverManager().install()

# %%
url= 'https://www.tripadvisor.es/'

# %%
lista= ['Tirana', 'Viena', 'Minsk', 'Sofia', 'Copenhague', 'Ljubljana', 'Tallin', 'Paris',
       'Atenas', 'Dublin', 'Roma', 'Vilna', 'Skopje', 'Chisinau', 'Amsterdam',
       'Lisboa', 'Praga', 'Estocolmo', 'Berlin', 'Bruselas', 'Sarajevo',
       'Zagreb', 'Bratislava', 'Helsinki', 'Budapest', 'Reykjavik', 'Riga',
       'Luxemburgo', 'La valeta', 'Oslo', 'Varsovia', 'Bucarest', 'Belgrado']

# %%
links= []
for e in tqdm(lista):
    driver=webdriver.Chrome(PATH)
    driver.get(url)
    time.sleep(3)
    driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
    driver.execute_script('window.scrollTo(0, 200);')
    buscar= driver.find_element(By.XPATH, '//*[@id="lithium-root"]/main/div[3]/div/div/div/form/input[1]')
    buscar.click()  
    buscar.send_keys(e)
    time.sleep(1)
    buscar.send_keys(Keys.DOWN, Keys.RETURN)
    time.sleep(3)
    if e == 'Luxemburgo':
        driver.execute_script('window.scrollTo(0, 1200);')
        j= driver.find_elements(By.CLASS_NAME, 'Fofmq')[2]
        links += [j.find_element(By.TAG_NAME, 'a').get_attribute('href')]
    else:
        driver.execute_script('window.scrollTo(0, 1800);')
        j = driver.find_elements(By.CLASS_NAME, 'BYvbL')[1]
        links += [j.find_element(By.TAG_NAME, 'a').get_attribute('href')]
    driver.quit()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 33/33 [08:50<00:00, 16.08s/it]

# %%
data = pd.DataFrame(columns= ['ciudad', 'links'])

# %%
data.ciudad=lista
data.links=links

# %%
link_nocturno= []
link_monumentos = []
link_acuaticos= []
link_museos= []
link_spas= []
link_diversion= []
link_naturaleza= []

for e in links:
    if 'Luxembourg' in e or 'Serbia' in e:
        link = e.split('oa0')
    else:
        link = e.split('c42')
    link_nocturno.append(link[0] + 'c20' + link[1])
    link_monumentos.append(link[0] + 'c47' + link[1])
    link_acuaticos.append(link[0] + 'c55' + link[1])
    link_museos.append(link[0] + 'c49' + link[1])
    link_spas.append(link[0] + 'c40' + link[1])
    link_diversion.append(link[0] + 'c56' + link[1])
    link_naturaleza.append(link[0] + 'c57' + link[1])

# %%
data['link_nocturno']= link_nocturno
data['link_monumentos']= link_monumentos
data['link_acuaticos']= link_acuaticos
data['link_museos']= link_museos
data['link_spas']= link_spas
data['link_diversion']= link_diversion
data['link_naturaleza']= link_naturaleza

# %%
vida_nocturna= []
for e in tqdm(data.link_nocturno):
    driver=webdriver.Chrome(PATH)
    driver.get(e)
    time.sleep(3)
    driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
    time.sleep(2)
    driver.execute_script('window.scrollTo(0, 1300);')
    driver.find_element(By.XPATH, '//*[@id="rating_filter_contents"]/ul/li[2]/div/span/div[1]/label/span').click()
    time.sleep(1)
    vida_nocturna.append(driver.find_element(By.XPATH, '//*[@id="lithium-root"]/main/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[3]/div/div[2]/div/div/section[1]/div/div/div/span[1]/span').text)
    driver.quit()
data['vida_nocturna']= vida_nocturna
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 33/33 [08:17<00:00, 15.07s/it]

# %%
monumentos= []
for e in tqdm(data.link_monumentos):
    driver=webdriver.Chrome(PATH)
    driver.get(e)
    time.sleep(3)
    driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, 1300);')
    driver.find_element(By.XPATH, '//*[@id="rating_filter_contents"]/ul/li[2]/div/span/div[1]/label/span').click()
    time.sleep(2)
    monumentos.append(driver.find_element(By.XPATH, '//*[@id="lithium-root"]/main/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[3]/div/div[2]/div/div/section[1]/div/div/div/span[1]/span').text)
    driver.quit()
data['monumentos'] = monumentos
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 33/33 [08:28<00:00, 15.42s/it]

# %%
deportes_agua= []
for e in tqdm(data.link_acuaticos):
    driver=webdriver.Chrome(PATH)
    driver.get(e)
    time.sleep(3)
    driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
    time.sleep(1)
    deportes_agua.append(driver.find_element(By.XPATH, '//*[@id="lithium-root"]/main/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[3]/div/div[2]/div/div/section[1]/div/div/div/span[1]/span').text)
    driver.quit()
data['deportes_agua'] = deportes_agua
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 33/33 [07:11<00:00, 13.08s/it]

# %%
museos= []
for e in tqdm(data.link_museos):
    driver=webdriver.Chrome(PATH)
    driver.get(e)
    time.sleep(3)
    driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
    if 'Skopje' in e:
        museos.append(driver.find_element(By.XPATH, '//*[@id="lithium-root"]/main/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[3]/div/div[2]/div/div/section[1]/div/div/div/span[1]/span').text)
    else:
        driver.execute_script('window.scrollTo(0, 1800);')
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="rating_filter_contents"]/ul/li[2]/div/span/div[1]/label/span').click()
        time.sleep(2)
        museos.append(driver.find_element(By.XPATH, '//*[@id="lithium-root"]/main/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[3]/div/div[2]/div/div/section[1]/div/div/div/span[1]/span').text)
    driver.quit()
data['museos'] = museos
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 33/33 [08:51<00:00, 16.09s/it]

# %%
spas= []
for e in tqdm(data.link_spas):
    driver=webdriver.Chrome(PATH)
    driver.get(e)
    time.sleep(3)
    driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
    if 'Skopje' in e or 'Chisinau' in e or 'Sarajevo' in e or 'Valletta' in e:
        spas.append(driver.find_element(By.XPATH, '//*[@id="lithium-root"]/main/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[3]/div/div[2]/div/div/section[1]/div/div/div/span[1]/span').text)
    else:
        driver.execute_script('window.scrollTo(0, 1800);')
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="rating_filter_contents"]/ul/li[2]/div/span/div[1]/label/span').click()
        time.sleep(2)
        spas.append(driver.find_element(By.XPATH, '//*[@id="lithium-root"]/main/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[3]/div/div[2]/div/div/section[1]/div/div/div/span[1]/span').text)
    driver.quit()
data['spas'] = spas
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 33/33 [08:35<00:00, 15.61s/it]

# %%
diversion= []
for e in tqdm(data.link_diversion):
    driver=webdriver.Chrome(PATH)
    driver.get(e)
    time.sleep(3)
    driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
    driver.execute_script('window.scrollTo(0, 1300);')
    time.sleep(1)
    driver.find_element(By.XPATH, '//*[@id="rating_filter_contents"]/ul/li[2]/div/span/div[1]/label/span').click()
    time.sleep(1)
    diversion.append(driver.find_element(By.XPATH, '//*[@id="lithium-root"]/main/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[3]/div/div[2]/div/div/section[1]/div/div/div/span[1]/span').text)
    driver.quit()
data['diversion']= diversion
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 33/33 [08:24<00:00, 15.29s/it]

# %%
naturaleza= []
for e in tqdm(data.link_naturaleza):
    driver=webdriver.Chrome(PATH)
    driver.get(e)
    time.sleep(3)
    driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
    if  'Sarajevo' in e or 'Valletta' in e:
        naturaleza.append(driver.find_element(By.XPATH, '//*[@id="lithium-root"]/main/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[3]/div/div[2]/div/div/section[1]/div/div/div/span[1]/span').text)
    else:
        driver.execute_script('window.scrollTo(0, 1800);')
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="rating_filter_contents"]/ul/li[2]/div/span/div[1]/label/span').click()
        time.sleep(1)
        naturaleza.append(driver.find_element(By.XPATH, '//*[@id="lithium-root"]/main/div[1]/div/div[3]/div/div[2]/div[2]/div[2]/div/div[3]/div/div[2]/div/div/section[1]/div/div/div/span[1]/span').text)
    driver.quit()
data['naturaleza']= naturaleza
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████|
# 5   54 lugares ordenados por favoritos de los viaj...
# 6   52 lugares ordenados por favoritos de los viaj...
# 7   329 lugares ordenados por favoritos de los via...
# 8   169 lugares ordenados por favoritos de los via...
# 9   212 lugares ordenados por favoritos de los via...
# 10  327 lugares ordenados por favoritos de los via...
# 11  56 lugares ordenados por favoritos de los viaj...
# 12  21 lugares ordenados por favoritos de los viaj...
# 13  21 lugares ordenados por favoritos de los viaj...
# 14  381 lugares ordenados por favoritos de los via...
# 15  157 lugares ordenados por favoritos de los via...
# 16  404 lugares ordenados por favoritos de los via...
# 17  20 lugares ordenados por favoritos de los viaj...
# 18  372 lugares ordenados por favoritos de los via...
# 19  107 lugares ordenados por favoritos de los via...
# 20  27 lugares ordenados por favoritos de los viaj...
# 21  83 lugares ordenados por favoritos de los viaj...
# 22  61 lugares ordenados por favoritos de los viaj...
# 23  50 lugares ordenados por favoritos de los viaj...
# 24  213 lugares ordenados por favoritos de los via...
# 25  40 lugares ordenados por favoritos de los viaj...
# 26  63 lugares ordenados por favoritos de los viaj...
# 27  16 lugares ordenados por favoritos de los viaj...
# 28  7 lugares ordenados por favoritos de los viaje...
# 29  48 lugares ordenados por favoritos de los viaj...
# 30  93 lugares ordenados por favoritos de los viaj...
# 31  103 lugares ordenados por favoritos de los via...
# 32  129 lugares ordenados por favoritos de los via...
#
#                                            monumentos  \
# 0   30 lugares ordenados por favoritos de los viaj...
# 1   295 lugares ordenados por favoritos de los via...
# 2   68 lugares ordenados por favoritos de los viaj...
# 3   110 lugares ordenados por favoritos de los via...
# 4   174 lugares ordenados por favoritos de los via...
# 5   67 lugares ordenados por favoritos de los viaj...
# 6   92 lugares ordenados por favoritos de los viaj...
# 7   1.000+ lugares ordenados por favoritos de los ...
# 8   259 lugares ordenados por favoritos de los via...
# 9   270 lugares ordenados por favoritos de los via...
# 10  926 lugares ordenados por favoritos de los via...
# 11  105 lugares ordenados por favoritos de los via...
# 12  34 lugares ordenados por favoritos de los viaj...
# 13  35 lugares ordenados por favoritos de los viaj...
# 14  256 lugares ordenados por favoritos de los via...
# 15  430 lugares ordenados por favoritos de los via...
# 16  581 lugares ordenados por favoritos de los via...
# 17  133 lugares ordenados por favoritos de los via...
# 18  380 lugares ordenados por favoritos de los via...
# 19  238 lugares ordenados por favoritos de los via...
# 20  70 lugares ordenados por favoritos de los viaj...
# 21  52 lugares ordenados por favoritos de los viaj...
# 22  105 lugares ordenados por favoritos de los via...
# 23  177 lugares ordenados por favoritos de los via...
# 24  242 lugares ordenados por favoritos de los via...
# 25  47 lugares ordenados por favoritos de los viaj...
# 26  102 lugares ordenados por favoritos de los via...
# 27  138 lugares ordenados por favoritos de los via...
# 28  110 lugares ordenados por favoritos de los via...
# 29  156 lugares ordenados por favoritos de los via...
# 30  197 lugares ordenados por favoritos de los via...
# 31  106 lugares ordenados por favoritos de los via...
# 32  79 lugares ordenados por favoritos de los viaj...
#
#                                         deportes_agua  \
# 0   27 lugares ordenados por favoritos de los viaj...
# 1   9 lugares ordenados por favoritos de los viaje...
# 2   6 lugares ordenados por favoritos de los viaje...
# 3   7 lugares ordenados por favoritos de los viaje...
# 4   5 lugares ordenados por favoritos de los viaje...
# 5   6 lugares ordenados por favoritos de los viaje...
# 6   18 lugares ordenados por favoritos de los viaj...
# 7   100 lugares ordenados por favoritos de los via...
# 8   107 lugares ordenados por favoritos de los via...
# 9   5 lugares ordenados por favoritos de los viaje...
# 10  42 lugares ordenados por favoritos de los viaj...
# 11  8 lugares ordenados por favoritos de los viaje...
# 12  10 lugares ordenados por favoritos de los viaj...
# 13  4 lugares ordenados por favoritos de los viaje...
# 14  143 lugares ordenados por favoritos de los via...
# 15  137 lugares ordenados por favoritos de los via...
# 16  44 lugares ordenados por favoritos de los viaj...
# 17  22 lugares ordenados por favoritos de los viaj...
# 18  10 lugares ordenados por favoritos de los viaj...
# 19  9 lugares ordenados por favoritos de los viaje...
# 20  9 lugares ordenados por favoritos de los viaje...
# 21  18 lugares ordenados por favoritos de los viaj...
# 22  6 lugares ordenados por favoritos de los viaje...
# 23  27 lugares ordenados por favoritos de los viaj...
# 24  62 lugares ordenados por favoritos de los viaj...
# 25  60 lugares ordenados por favoritos de los viaj...
# 26  30 lugares ordenados por favoritos de los viaj...
# 27  5 lugares ordenados por favoritos de los viaje...
# 28  18 lugares ordenados por favoritos de los viaj...
# 29  15 lugares ordenados por favoritos de los viaj...
# 30  6 lugares ordenados por favoritos de los viaje...
# 31  11 lugares ordenados por favoritos de los viaj...
# 32  5 lugares ordenados por favoritos de los viaje...
#
#                                                museos  \
# 0   14 lugares ordenados por favoritos de los viaj...
# 1   119 lugares ordenados por favoritos de los via...
# 2   45 lugares ordenados por favoritos de los viaj...
# 3   47 lugares ordenados por favoritos de los viaj...
# 4   66 lugares ordenados por favoritos de los viaj...
# 5   30 lugares ordenados por favoritos de los viaj...
# 6   75 lugares ordenados por favoritos de los viaj...
# 7   231 lugares ordenados por favoritos de los via...
# 8   89 lugares ordenados por favoritos de los viaj...
# 9   81 lugares ordenados por favoritos de los viaj...
# 10  181 lugares ordenados por favoritos de los via...
# 11  58 lugares ordenados por favoritos de los viaj...
# 12  12 lugares ordenados por favoritos de los viaj...
# 13  12 lugares ordenados por favoritos de los viaj...
# 14  149 lugares ordenados por favoritos de los via...
# 15  109 lugares ordenados por favoritos de los via...
# 16  212 lugares ordenados por favoritos de los via...
# 17  62 lugares ordenados por favoritos de los viaj...
# 18  194 lugares ordenados por favoritos de los via...
# 19  98 lugares ordenados por favoritos de los viaj...
# 20  24 lugares ordenados por favoritos de los viaj...
# 21  42 lugares ordenados por favoritos de los viaj...
# 22  39 lugares ordenados por favoritos de los viaj...
# 23  59 lugares ordenados por favoritos de los viaj...
# 24  116 lugares ordenados por favoritos de los via...
# 25  39 lugares ordenados por favoritos de los viaj...
# 26  65 lugares ordenados por favoritos de los viaj...
# 27  42 lugares ordenados por favoritos de los viaj...
# 28  21 lugares ordenados por favoritos de los viaj...
# 29  69 lugares ordenados por favoritos de los viaj...
# 30  72 lugares ordenados por favoritos de los viaj...
# 31  51 lugares ordenados por favoritos de los viaj...
# 32  47 lugares ordenados por favoritos de los viaj...
#
#                                                  spas  \
# 0   23 lugares ordenados por favoritos de los viaj...
# 1   41 lugares ordenados por favoritos de los viaj...
# 2   20 lugares ordenados por favoritos de los viaj...
# 3   47 lugares ordenados por favoritos de los viaj...
# 4   41 lugares ordenados por favoritos de los viaj...
# 5   24 lugares ordenados por favoritos de los viaj...
# 6   23 lugares ordenados por favoritos de los viaj...
# 7   304 lugares ordenados por favoritos de los via...
# 8   62 lugares ordenados por favoritos de los viaj...
# 9   59 lugares ordenados por favoritos de los viaj...
# 10  184 lugares ordenados por favoritos de los via...
# 11  38 lugares ordenados por favoritos de los viaj...
# 12  13 lugares ordenados por favoritos de los viaj...
# 13  18 lugares ordenados por favoritos de los viaj...
# 14  88 lugares ordenados por favoritos de los viaj...
# 15  125 lugares ordenados por favoritos de los via...
# 16  136 lugares ordenados por favoritos de los via...
# 17  24 lugares ordenados por favoritos de los viaj...
# 18  111 lugares ordenados por favoritos de los via...
# 19  34 lugares ordenados por favoritos de los viaj...
# 20  13 lugares ordenados por favoritos de los viaj...
# 21  27 lugares ordenados por favoritos de los viaj...
# 22  17 lugares ordenados por favoritos de los viaj...
# 23  38 lugares ordenados por favoritos de los viaj...
# 24  118 lugares ordenados por favoritos de los via...
# 25  21 lugares ordenados por favoritos de los viaj...
# 26  89 lugares ordenados por favoritos de los viaj...
# 27  17 lugares ordenados por favoritos de los viaj...
# 28  2 lugares ordenados por favoritos de los viaje...
# 29  18 lugares ordenados por favoritos de los viaj...
# 30  88 lugares ordenados por favoritos de los viaj...
# 31  58 lugares ordenados por favoritos de los viaj...
# 32  44 lugares ordenados por favoritos de los viaj...
#
#                                             diversion  \
# 0   18 lugares ordenados por favoritos de los viaj...
# 1   106 lugares ordenados por favoritos de los via...
# 2   64 lugares ordenados por favoritos de los viaj...
# 3   76 lugares ordenados por favoritos de los viaj...
# 4   58 lugares ordenados por favoritos de los viaj...
# 5   35 lugares ordenados por favoritos de los viaj...
# 6   59 lugares ordenados por favoritos de los viaj...
# 7   227 lugares ordenados por favoritos de los via...
# 8   77 lugares ordenados por favoritos de los viaj...
# 9   72 lugares ordenados por favoritos de los viaj...
# 10  134 lugares ordenados por favoritos de los via...
# 11  47 lugares ordenados por favoritos de los viaj...
# 12  13 lugares ordenados por favoritos de los viaj...
# 13  19 lugares ordenados por favoritos de los viaj...
# 14  121 lugares ordenados por favoritos de los via...
# 15  59 lugares ordenados por favoritos de los viaj...
# 16  254 lugares ordenados por favoritos de los via...
# 17  52 lugares ordenados por favoritos de los viaj...
# 18  129 lugares ordenados por favoritos de los via...
# 19  51 lugares ordenados por favoritos de los viaj...
# 20  16 lugares ordenados por favoritos de los viaj...
# 21  46 lugares ordenados por favoritos de los viaj...
# 22  67 lugares ordenados por favoritos de los viaj...
# 23  56 lugares ordenados por favoritos de los viaj...
# 24  173 lugares ordenados por favoritos de los via...
# 25  28 lugares ordenados por favoritos de los viaj...
# 26  80 lugares ordenados por favoritos de los viaj...
# 27  26 lugares ordenados por favoritos de los viaj...
# 28  4 lugares ordenados por favoritos de los viaje...
# 29  41 lugares ordenados por favoritos de los viaj...
# 30  104 lugares ordenados por favoritos de los via...
# 31  84 lugares ordenados por favoritos de los viaj...
# 32  48 lugares ordenados por favoritos de los viaj...
#
#                                            naturaleza
# 0   7 lugares ordenados por favoritos de los viaje...
# 1   48 lugares ordenados por favoritos de los viaj...
# 2   17 lugares ordenados por favoritos de los viaj...
# 3   26 lugares ordenados por favoritos de los viaj...
# 4   46 lugares ordenados por favoritos de los viaj...
# 5   10 lugares ordenados por favoritos de los viaj...
# 6   25 lugares ordenados por favoritos de los viaj...
# 7   156 lugares ordenados por favoritos de los via...
# 8   20 lugares ordenados por favoritos de los viaj...
# 9   58 lugares ordenados por favoritos de los viaj...
# 10  73 lugares ordenados por favoritos de los viaj...
# 11  12 lugares ordenados por favoritos de los viaj...
# 12  8 lugares ordenados por favoritos de los viaje...
# 13  11 lugares ordenados por favoritos de los viaj...
# 14  54 lugares ordenados por favoritos de los viaj...
# 15  55 lugares ordenados por favoritos de los viaj...
# 16  75 lugares ordenados por favoritos de los viaj...
# 17  57 lugares ordenados por favoritos de los viaj...
# 18  96 lugares ordenados por favoritos de los viaj...
# 19  29 lugares ordenados por favoritos de los viaj...
# 20  9 lugares ordenados por favoritos de los viaje...
# 21  16 lugares ordenados por favoritos de los viaj...
# 22  33 lugares ordenados por favoritos de los viaj...
# 23  54 lugares ordenados por favoritos de los viaj...
# 24  52 lugares ordenados por favoritos de los viaj...
# 25  20 lugares ordenados por favoritos de los viaj...
# 26  19 lugares ordenados por favoritos de los viaj...
# 27  42 lugares ordenados por favoritos de los viaj...
# 28  4 lugares ordenados por favoritos de los viaje...
# 29  56 lugares ordenados por favoritos de los viaj...
# 30  40 lugares ordenados por favoritos de los viaj...
# 31  27 lugares ordenados por favoritos de los viaj...
# 32  18 lugares ordenados por favoritos de los viaj...

# %%
data.vida_nocturna=data.vida_nocturna.apply(lambda x: int(re.findall('[0-9]+', x)[0]))
data.monumentos=data.monumentos.apply(lambda x: int(re.findall('[0-9]+', x)[0]))
data.deportes_agua=data.deportes_agua.apply(lambda x: int(re.findall('[0-9]+', x)[0]))
data.museos=data.museos.apply(lambda x: int(re.findall('[0-9]+', x)[0]))
data.spas=data.spas.apply(lambda x: int(re.findall('[0-9]+', x)[0]))
data.diversion=data.diversion.apply(lambda x: int(re.findall('[0-9]+', x)[0]))
data.naturaleza=data.naturaleza.apply(lambda x: int(re.findall('[0-9]+', x)[0]))

# %%
data.to_excel('links.xlsx', index = False)
